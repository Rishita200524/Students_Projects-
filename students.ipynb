# %%
import pandas as pd

# %%
ds=pd.read_csv("Pass-Fail Data.csv")

# %%
ds.head()
# Out:
#    student_id  attendance_pct  homework_pct  midterm_score  \
# 0           1              95            92             88
# 1           2              88            85             79
# 2           3              60            55             58
# 3           4              72            70             65
# 4           5              40            45             50
#
#    study_hours_per_week  pass
# 0                    12     1
# 1                    10     1
# 2                     4     0
# 3                     6     1
# 4                     3     0

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            100 non-null    int64
#  1   attendance_pct        100 non-null    int64
#  2   homework_pct          100 non-null    int64
#  3   midterm_score         100 non-null    int64
#  4   study_hours_per_week  100 non-null    int64
#  5   pass                  100 non-null    int64
# dtypes: int64(6)
# memory usage: 4.8 KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x=ds.drop("pass",axis=1)
y=ds["pass"]

# %%
y
# Out:
# 0     1
# 1     1
# 2     0
# 3     1
# 4     0
#      ..
# 95    1
# 96    1
# 97    0
# 98    1
# 99    0
# Name: pass, Length: 100, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
ds.shape
# Out:
# (100, 6)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import joblib
joblib.dump(model,'student_pass-fail.pkl')
# Out:
# ['student_pass-fail.pkl']

# %%
print(x_train.shape)
# Out:
# (80, 5)

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([ 0.79708654,  0.75707682, -0.29854237,  0.45095096,  1.09666932,
#         0.58918597, -0.33349476,  0.20741214, -0.44255809,  1.23198817,
#         1.12294881,  1.10066307, -0.0251075 ,  0.69542285,  1.15344957,
#        -0.15365743,  0.98214612,  0.10340971,  0.69254342,  0.97700302])

# %%
x_test
# Out:
#     student_id  attendance_pct  homework_pct  midterm_score  \
# 83          84              78            75             73
# 53          54              77            73             71
# 70          71              34            39             44
# 45          46              64            61             60
# 44          45              93            94             95
# 39          40              69            66             64
# 22          23              35            40             48
# 80          81              56            54             56
# 10          11              30            35             42
# 0            1              95            92             88
# 18          19              88            90             86
# 30          31              91            89             87
# 73          74              50            47             52
# 33          34              73            71             69
# 90          91              93            92             90
# 4            5              40            45             50
# 76          77              81            87             85
# 77          78              47            53             55
# 12          13              74            70             68
# 31          32              84            82             79
#
#     study_hours_per_week
# 83                     8
# 53                     8
# 70                     2
# 45                     5
# 44                    15
# 39                     6
# 22                     2
# 80                     4
# 10                     2
# 0                     12
# 18                    12
# 30                    12
# 73                     4
# 33                     7
# 90                    13
# 4                      3
# 76                    10
# 77                     3
# 12                     7
# 31                     9

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
r2=r2_score(y_test,pred)
print(r2)
# Out:
# 0.7402973094289826

# %%
import numpy as np
mse=mean_squared_error(y_test,pred)
rmse=np.sqrt(mse)

# %%
print(mse)
print(rmse)
# Out:
# 0.062328645737044185
# 0.2496570562532615
